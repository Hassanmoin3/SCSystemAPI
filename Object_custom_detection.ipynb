# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
# !drive.mount("/content/drive", force_remount=True).
# Out:
# /bin/bash: -c: line 0: syntax error near unexpected token `"/content/drive",'
# /bin/bash: -c: line 0: `drive.mount("/content/drive", force_remount=True).'

# %%
# !ls '/content/drive/My Drive/yolo_custom_model_training'
# Out:
# CUSTOMS_DATA

# %%
# !unzip '/content/drive/My Drive/yolo_custom_model_training/CUSTOMS_DATA.zip' -d '/content/drive/My Drive/yolo_custom_model_training/'
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: /content/drive/My Drive/yolo_custom_model_training/CUSTOMS_DATA/2374.JPG
#   inflating: /content/drive/My Drive/yolo_custom_model_training/CUSTOMS_DATA/2374.txt
#   inflating: /content/drive/My Drive/yolo_custom_model_training/CUSTOMS_DATA/2375.JPG
#   inflating: /content/drive/My Drive/yolo_custom_model_training/CUSTOMS_DATA/2375.txt
#   inflating: /content/drive/My Drive/yolo_custom_model_training/CUSTOMS_DATA/2376.JPG
#   inflating: /content/drive/My Drive/yolo_custom_model_training/CUSTOMS_DATA/2376.txt
#   inflating: /content/drive/My Drive/yolo_custom_model_training/CUSTOMS_DATA/2377.JPG
#   inflating: /content/drive/My Drive/yolo_custom_model_training/CUSTOMS_DATA/2377.txt
#   inflating: /content/drive/My Drive/yolo_custom_model_training/CUSTOMS_DATA/2378.JPG
#   inflating: /content/drive/My Drive/yolo_custom_model_training/CUSTOMS_DATA/2378.txt
# ...

# %%
# %cd /content/drive/My Drive/yolo_custom_model_training
# Out:
# /content/drive/My Drive/yolo_custom_model_training

# %% [markdown]
# # New Section

# %%
# !git clone 'https://github.com/AlexeyAB/darknet.git' '/content/drive/My Drive/yolo_custom_model_training/darknet'
# Out:
# Cloning into '/content/drive/My Drive/yolo_custom_model_training/darknet'...
# remote: Enumerating objects: 15308, done.
# remote: Total 15308 (delta 0), reused 0 (delta 0), pack-reused 15308
# Receiving objects: 100% (15308/15308), 13.66 MiB | 5.95 MiB/s, done.
# Resolving deltas: 100% (10404/10404), done.
# Checking out files: 100% (2044/2044), done.

# %%
# %cd /content/drive/My Drive/yolo_custom_model_training/darknet
# Out:
# /content/drive/My Drive/yolo_custom_model_training/darknet

# %%
# !ls
# Out:
# 3rdparty		darknet_video.py       net_cam_v4.sh
# build			data		       README.md
# build.ps1		image_yolov3.sh        results
# cfg			image_yolov4.sh        scripts
# cmake			include		       src
# CMakeLists.txt		json_mjpeg_streams.sh  vcpkg.json
# DarknetConfig.cmake.in	LICENSE		       video_yolov3.sh
# darknet_images.py	Makefile	       video_yolov4.sh
# darknet.py		net_cam_v3.sh

# %%
# !make
# Out:
# chmod +x *.sh
# g++ -std=c++11 -std=c++11 -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/image_opencv.cpp -o obj/image_opencv.o
# ./src/image_opencv.cpp: In function ‘void draw_detections_cv_v3(void**, detection*, int, float, char**, image**, int, int)’:
# ./src/image_opencv.cpp:946:23: warning: variable ‘rgb’ set but not used [-Wunused-but-set-variable]
#                  float rgb[3];
#                        ^~~
# ./src/image_opencv.cpp: In function ‘void draw_train_loss(char*, void**, int, float, float, int, int, float, int, char*, float, int, int, double)’:
# ./src/image_opencv.cpp:1147:13: warning: this ‘if’ clause does not guard... [-Wmisleading-indentation]
#              if (iteration_old == 0)
#              ^~
# ...

# %%
# !chmod +x *.sh

# %%
# %cd /content/drive/My Drive/yolo_custom_model_training
# Out:
# /content/drive/My Drive/yolo_custom_model_training

# %%
# !python CUSTOMS_DATA/creating-files-data-and-name.py

# %%
# !python CUSTOMS_DATA/creating-train-and-test-txt-files.py

# %%
# %cd /content/drive/My Drive/yolo_custom_model_training
# Out:
# /content/drive/My Drive/yolo_custom_model_training

# %%
# !ls
# Out:
# backup	  chart.png		   CUSTOMS_DATA   darknet
# bad.list  chart_yolov3_custom.png  custom_weight

# %%
# !nvcc --version
# !nvidia-smi
# Out:
# nvcc: NVIDIA (R) Cuda compiler driver
# Copyright (c) 2005-2020 NVIDIA Corporation
# Built on Wed_Jul_22_19:09:09_PDT_2020
# Cuda compilation tools, release 11.0, V11.0.221
# Build cuda_11.0_bu.TC445_37.28845127_0
# Thu Aug 26 17:17:38 2021
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 470.57.02    Driver Version: 460.32.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla K80           Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   34C    P8    24W / 149W |      0MiB / 11441MiB |      0%      Default |
# ...

# %%
 # !chmod +x ./darknet/darknet

# %%
# !darknet/darknet detector train CUSTOMS_DATA/labelled_data.data darknet/cfg/yolov3_custom.cfg backup/yolov3_custom_last.weights -dont_show
# Out:
# /bin/bash: darknet/darknet: Permission denied

# %%
# !darknet/darknet detector train CUSTOMS_DATA/labelled_data.data darknet/cfg/yolov3_custom.cfg backup/yolov3_custom_last.weights -dont_show
# Out:
# Streaming output truncated to the last 5000 lines.
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 106 Avg (IOU: 0.000000), count: 1, class_loss = 0.000208, iou_loss = 0.000000, total_loss = 0.000208
#  total_bbox = 35096, rewritten_bbox = 0.039891 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 82 Avg (IOU: 0.403988), count: 4, class_loss = 1.819418, iou_loss = 1.740755, total_loss = 3.560173
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 94 Avg (IOU: 0.429078), count: 8, class_loss = 9.022479, iou_loss = 3.817134, total_loss = 12.839613
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 106 Avg (IOU: 0.000000), count: 1, class_loss = 0.000220, iou_loss = 0.000000, total_loss = 0.000220
#  total_bbox = 35108, rewritten_bbox = 0.039877 %
# ...
